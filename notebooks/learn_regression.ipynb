# %%
from pyAudioAnalysis import audioTrainTest as aT
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/hiroshi/study_midi_audio_classification/env/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
# ...

# %%
folder_tag = 'midi_audio_sample20180819013100'
model_types = ['svm', 'svm_rbf', 'randomforest']
data_folder = './{0}/teacher'.format(folder_tag)

# %%
for model_info in [('./{0}/{1}'.format(folder_tag, model_type), model_type) for model_type in model_types]:
    print('learning model is ', model_info)
    model_suffix = model_info[0]
    model_type = model_info[1]
    aT.featureAndTrainRegression(data_folder, 1, 1, aT.shortTermWindow, aT.shortTermStep, model_type, model_suffix, False)
# Out:
# learning model is  ('./midi_audio_sample20180818164230/randomforest', 'randomforest')
# Analyzing file 1 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree60-volume40.mid.wav.ogg
# Analyzing file 2 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree60-volume70.mid.wav.ogg
# Analyzing file 3 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree62-volume40.mid.wav.ogg
# Analyzing file 4 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree62-volume70.mid.wav.ogg
# Analyzing file 5 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree64-volume100.mid.wav.ogg
# Analyzing file 6 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree65-volume100.mid.wav.ogg
# Analyzing file 7 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree65-volume70.mid.wav.ogg
# Analyzing file 8 of 194: ./midi_audio_sample20180818164230/teacher/note-program0-degree67-volume100.mid.wav.ogg
# ...
